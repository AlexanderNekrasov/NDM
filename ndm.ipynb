# %%
# %load_ext autoreload
# %autoreload 2

# %%
import wandb
#wandb.login()

# %%
import main_ndm

config = {
    "experiment_name": "ndm_1000steps",
    "wandb_logging": False,
    "dataset": "checkerboard",
    "train_batch_size": 256,
    "eval_batch_size": 10000,
    "num_epochs": 1000,
    "learning_rate": 1e-4,
    "num_timesteps": 1000,
    # "schedule_config": {"type": "cosine", "min_alpha": 0.0001, "max_alpha": 0.9999},
    "schedule_config": {"type": "linear", "beta_start": 0.0001, "beta_end": 0.02},
    "embedding_size": 128,
    "hidden_size": 512,
    "hidden_layers": 5,
    "save_images_step": 20,
    "gradient_clipping": None,
    "dataset_size": 80000,
    "importance_sampling_batch_size": None,
    "uniform_prob": 0.001,
    "optimizer_type": "sgd",
    "momentum": 0.9,
    "weight_decay": 0.0001,
    # New parameters for model loading
    "load_pretrained": False,
    "pretrained_run_id": "ndm/esjakfmk",  # wandb run ID to load model from
    "pretrained_model_path": "exps/ndm_1000steps/model.pth",  # local path to load model from (alternative to wandb)
    "pretrained_epochs": 1000,  # number of epochs the pretrained model was trained for
}

main_ndm.run(config, do_plots=True)
# Out:
# Using device: cuda
# alphas_cumpod: tensor([9.9990e-01, 9.9978e-01, 9.9964e-01,  ..., 4.1599e-05, 4.0767e-05,
#         3.9952e-05])
# Training model...
# Epoch 0
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 0 finished with loss: 10.782067755858103
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 1
# Epoch 1 finished with loss: 10.279658029476801
# Epoch 2
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 2 finished with loss: 10.359343115335856
# Epoch 3
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 3 finished with loss: 10.341713942778416
# Epoch 4
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 4 finished with loss: 9.685433888282532
# Epoch 5
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 5 finished with loss: 9.725833855378323
# Epoch 6
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 6 finished with loss: 9.287732694393549
# Epoch 7
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 7 finished with loss: 9.362911767684496
# Epoch 8
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 8 finished with loss: 8.74329053132962
# Epoch 9
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 9 finished with loss: 9.06457010599283
# Epoch 10
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 10 finished with loss: 9.379234663951092
# Epoch 11
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 11 finished with loss: 8.379449219275743
# Epoch 12
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 12 finished with loss: 9.015511612097422
# Epoch 13
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 13 finished with loss: 8.592715854064013
# Epoch 14
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 14 finished with loss: 8.771622888552837
# Epoch 15
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 15 finished with loss: 8.596945924636644
# Epoch 16
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 16 finished with loss: 8.375447433728437
# Epoch 17
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 17 finished with loss: 9.011633535990349
# Epoch 18
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 18 finished with loss: 9.096521044388796
# Epoch 19
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 19 finished with loss: 8.784611089871479
# Epoch 20
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 20 finished with loss: 9.167500492853996
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 21
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 21 finished with loss: 9.001555037039976
# Epoch 22
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 22 finished with loss: 8.33517943437283
# Epoch 23
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 23 finished with loss: 8.40632764269144
# Epoch 24
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 24 finished with loss: 8.833058682007668
# Epoch 25
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 25 finished with loss: 8.046675488734857
# Epoch 26
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 26 finished with loss: 8.958928870849121
# Epoch 27
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 27 finished with loss: 8.651927278592037
# Epoch 28
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 28 finished with loss: 8.803178205704077
# Epoch 29
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 83 finished with loss: 8.029673026922422
# Epoch 84
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 84 finished with loss: 7.77502808586145
# Epoch 85
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 85 finished with loss: 7.915233626579627
# Epoch 86
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 86 finished with loss: 7.8386577153817205
# Epoch 87
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 87 finished with loss: 8.50402650084251
# Epoch 88
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 88 finished with loss: 7.8490723104049
# Epoch 89
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 89 finished with loss: 8.539558401474586
# Epoch 90
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 90 finished with loss: 8.169773439566294
# Epoch 91
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 91 finished with loss: 7.946625332037608
# Epoch 92
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 92 finished with loss: 8.04070566021479
# Epoch 93
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 93 finished with loss: 8.08432801029621
# Epoch 94
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 94 finished with loss: 8.048649602211439
# Epoch 95
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 95 finished with loss: 7.842100281745959
# Epoch 96
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 96 finished with loss: 8.047741578175472
# Epoch 97
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 97 finished with loss: 8.156803073027195
# Epoch 98
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 98 finished with loss: 8.122520105961042
# Epoch 99
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 99 finished with loss: 7.825525558147675
# Epoch 100
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 100 finished with loss: 7.872206519811582
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 101
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 101 finished with loss: 8.035098244746527
# Epoch 102
#   0%|          | 0/312 [00:00<?, ?it/s]
# Epoch 102 finished with loss: 7.77762295343937
# Epoch 103
#   0%|          | 0/312 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5621/1834775248.py in <module>
#      30 }
#      31
# ---> 32 main_ndm.run(config, do_plots=True)
#
# ~/HSE/gans/ndm/NDM/main_ndm.py in run(config, do_plots)
#     123     for epoch in range(config["num_epochs"]):
#     124         print(f"Epoch {epoch}")
# --> 125         global_step, cur_losses = train_epoch(
#     126             ndm,
#     127             dataloader,
#
# ~/HSE/gans/ndm/NDM/ndm.py in train_epoch(ndm, dataloader, optimizer, scheduler, global_step, gradient_clipping)
#     211         )
#     212
# --> 213         noisy = ndm.add_noise(batch, noise, timesteps)
#     214         noise_pred = ndm.model(noisy, timesteps)
#     215         xhat = ndm.reconstruct_x0(noisy, timesteps, noise_pred)
#
# ~/HSE/gans/ndm/NDM/ndm.py in add_noise(self, x_start, x_noise, timesteps)
#     137         s2 = s2.reshape(-1, 1)
#     138
# --> 139         return s1 * self.F(x_start, timesteps) + s2 * x_noise
#     140
#     141     @torch.no_grad()
#
# ~/HSE/gans/ndm/NDM/ndm.py in F(self, x, t)
#      68             assert 0 <= t and t <= self.num_timesteps
#      69         t_scaled = t.view(-1, 1) / self.num_timesteps
# ---> 70         return (1 - t_scaled) * x + t_scaled * self.model_F(x, t)
#      71
#      72     def reconstruct_x0(self, z_t, t, noise):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# ~/HSE/gans/ndm/NDM/network.py in forward(self, x, t)
#      55         t_emb = self.time_mlp(t)
#      56         x = torch.cat((x1_emb, x2_emb, t_emb), dim=-1)
# ---> 57         x = self.joint_mlp(x)
#      58         return x
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# KeyboardInterrupt:
